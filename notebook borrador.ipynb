# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# ### ¿Somos libres de elegir lo que escuchamos?
#
# Como Spotify y sus principales playlist editoriales afectan al consumo musical y las listas de éxitos.

# %% [markdown]
# ### TEMA

# %% [markdown]
# Según un estudio realizado por la Federación Internacional de la Industria Fonográfica (IFPI) en 2022, del consumo musical total en España, el 34% fue en straming, ya sea por suscripción o con modelo freemium con anuncios. Si nos fijamos en la radio y la música comprada, representarían solo el 14% y 10% respectivamente. Si hablamos a nivel global, el 24% y 8% lo hacen por streaming de suscripción y freemium, y el 17% y 10% corresponderían a radio y ventas.
#
# En este estudio trataremos de ver la influencia de Spotify, plataforma de streaming por excelencia, en las listas de ventas españolas. ¿Por qué rara vez vemos artistas independientes copar las listas de éxitos? ¿Qué influencia tienen los sellos multinacionales en el algoritmo de Spotify y sus playlist internacionales?

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# La hipótesis principal del proyecto es que la música que escuchamos está influenciada, en gran medida por lo que el algoritmo de Spotify y sus playlist editoriales (influenciadas por grupos multinacionales como Sony, Universal o Warner con participación accionarial en la empresa). Para ver hasta donde llega esta influencia, compararemos la principal lista de ventas española (Promusicae) e internacional(Billboard Global), con sus homónimas en Spotify, así como las principales playlist editoriales.
#
# Tratando así de ver, por un lado, la influencia del streaming en las ventas totales, y la de las propias plataformas en la elección del consumo.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %% [markdown]
# Link playlist editoriales: https://developer.spotify.com/
#
# Ventas España: Promusicae (https://www.elportaldemusica.es/lists/top-100-canciones/2023/19)
#
# Ventas Global: Billboard Global 200 (https://www.billboard.com/charts/billboard-global-200/#)

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

df_esp = pd.read_csv('regional-es-weekly-2023-05-11.csv')

df_esp = df_esp.drop('uri', axis=1)

df_esp.rename(columns={'track_name': 'Track Name','source': 'Label','artist_names':'Artist'}, inplace=True)

df_esp
# Out:
#      rank                          Artist               Track Name
# 0       1                           Saiko                Supernova  \
# 1       2            Lola Indigo, Quevedo                 EL TONTO
# 2       3         ROSALÍA, Rauw Alejandro                     BESO
# 3       4                 Jhayco, Quevedo               Mami Chula
# 4       5       Marshmello, Manuel Turizo              El Merengue
# ..    ...                             ...                      ...
# 195   196        Sen Senra, Sky Rompiendo        Uno De Eses Gatos
# 196   197                        Anuel AA           ¿Qué Nos Pasó?
# 197   198         Aitana, Emilia, Ptazeta                  Quieres
# 198   199  Eladio Carrion, Bizarrap, Duki               Sin Frenos
# 199   200                  Álvaro De Luna  Juramento eterno de sal
#
#                                                  Label  peak_rank
# 0                                           2023 SAIKO          1  \
# 1                           Universal Music Spain S.L.          1
# 2    Columbia Records/Duars Entertainment/Sony Musi...          1
# 3                                N&E Entertainment LLC          4
# 4                                     Sony Music Latin          4
# ..                                                 ...        ...
# 195                         Universal Music Spain S.L.        196
# 196                          Real Hasta La Muerte, LLC         49
# 197                         Universal Music Spain S.L.         28
# 198                            Rimas Entertainment LLC         48
# 199                                           WM Spain         17
#
#      previous_rank  weeks_on_chart  streams
# 0                1               4  4946796
# 1                2               4  4836705
# 2                3               7  3799069
# 3                4               2  3728137
# 4                5              10  3444822
# ..             ...             ...      ...
# 195             -1               1   388634
# 196             -1              40   387323
# 197             -1              41   387066
# 198            188              54   385140
# 199             -1             110   383991
#
# [200 rows x 8 columns]

# %%
# Vamos a cambiar los nombres regionales de los sellos para poder agruparlos (por ejemplo: WM Spain, WM Mexico y WEA Latina = Warner Music)

df_esp ['Label'] = df_esp ['Label'].replace({'Sony Music Entertainment': 'Sony Music', 'Sony Music Latin': 'Sony Music', 'Columbia Records/Duars Entertainment/Sony Musi...': 'Sony Music', 'Sony Music Latin/DALE PLAY Records': 'Sony Music','Sony Music Argentina':'Sony Music','Sony Music Latin/Duars Entertainment':'Sony Music','Columbia':'Sony Music', 'Columbia Records/Duars Entertainment/Sony Music Latin': 'Sony Music'})
df_esp['Label'] = df_esp ['Label'].replace({'WM Spain' : 'Warner Music', 'WM Mexico': 'Warner Music', 'WEA Latina' : 'Warner Music'})
df_esp ['Label'] = df_esp ['Label'].replace({'UMLE - Latino' : 'Universal Music', 'Universal Music Spain S.L.' : 'Universal Music', 'Virgin Music Spain': 'Universal Music','Universal Music Argentina S.A.': 'Universal Music', 'Universal Music AB': 'Universal Music'})

frecuencias = df_esp ['Label'].value_counts()
valores_unicos = frecuencias[frecuencias == 1].index
df_esp.loc[df_esp['Label'].isin(valores_unicos), 'Label'] = 'Otros'

# Para que la representación gráfica del dataframe quede más limpia, 
# vamos a sustituir todos los valores que no están repetidos (todos ellos ellos y distribuidoras independientes) por el valor 'Otros'

porcentajes = df_esp['Label'].value_counts(normalize=True) * 100
valores = porcentajes.values
etiquetas = porcentajes.index
plt.pie(valores, labels=etiquetas, autopct='%1.1f%%')
plt.show()

# %%
df_int = pd.read_csv('regional-global-weekly-2023-05-11.csv')

df_int = df_int.drop('uri', axis=1)

df_int.rename(columns={'track_name': 'Track Name','source': 'Label','artist_names':'Artist'}, inplace=True)

df_int
# Out:
#      rank                           Artist         Track Name
# 0       1        Grupo Frontera, Bad Bunny          un x100to  \
# 1       2       Eslabon Armado, Peso Pluma    Ella Baila Sola
# 2       3            Yng Lvcas, Peso Pluma    La Bebe - Remix
# 3       4                      FIFTY FIFTY  Cupid - Twin Ver.
# 4       5                      Miley Cyrus            Flowers
# ..    ...                              ...                ...
# 195   196                      Frank Ocean       Pink + White
# 196   197                 Eminem, Dina Rae           Superman
# 197   198                     Taylor Swift       Shake It Off
# 198   199                           Hozier  Take Me To Church
# 199   200  Anuel AA, Mambo Kingz, DJ Luian  Mas Rica Que Ayer
#
#                                                 Label  peak_rank
# 0                            Rimas Entertainment LLC.          1  \
# 1                                         DEL Records          1
# 2                                           WM Mexico          3
# 3                                            WM Korea          4
# 4                                            Columbia          1
# ..                                                ...        ...
# 195                                    Boys Don't Cry        151
# 196                                         Aftermath        108
# 197                          Big Machine Records, LLC        143
# 198                     Universal-Island Records Ltd.        108
# 199  Real Hasta La Muerte, LLC & Hear This Music, LLC         57
#
#      previous_rank  weeks_on_chart   streams
# 0                1               4  49594770
# 1                2               8  48014265
# 2                3               8  39586315
# 3                5               8  36319569
# 4                4              17  33810864
# ..             ...             ...       ...
# 195            189               4   7648322
# 196            192              32   7645179
# 197             -1               2   7628964
# 198            187             103   7623544
# 199             -1               5   7575462
#
# [200 rows x 8 columns]

# %%
df_int ['Label'] = df_int ['Label'].replace({'Sony Music Entertainment': 'Sony Music', 'Sony Music Latin': 'Sony Music', 'Columbia Records/Duars Entertainment/Sony Musi...': 'Sony Music', 'Sony Music Latin/DALE PLAY Records': 'Sony Music','Sony Music Argentina':'Sony Music','Sony Music Latin/Duars Entertainment':'Sony Music','Columbia':'Sony Music', 'Columbia Records/Duars Entertainment/Sony Music Latin': 'Sony Music'})
df_int['Label'] = df_int ['Label'].replace({'WM Spain' : 'Warner Music', 'WM Mexico': 'Warner Music', 'WEA Latina' : 'Warner Music','WM Korea':'Warner Music'})
df_int ['Label'] = df_int ['Label'].replace({'UMLE - Latino' : 'Universal Music', 'Universal Music Spain S.L.' : 'Universal Music', 'Virgin Music Spain': 'Universal Music','Universal Music Argentina S.A.': 'Universal Music', 'Universal Music AB': 'Universal Music', 'Republic Records':'Universal Music','Universal Republic Records':'Universal Music','Universal-Island Records Ltd.':'Universal Msuic'})

frecuencias = df_int ['Label'].value_counts()
valores_unicos = frecuencias[frecuencias == 1].index
df_int.loc[df_int['Label'].isin(valores_unicos), 'Label'] = 'Otros'

porcentajes = df_int['Label'].value_counts(normalize=True) * 100
valores = porcentajes.values
etiquetas = porcentajes.index
plt.pie(valores, labels=etiquetas, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Continuamos visualizando las principales playlist editoriales nacionales: Éxitos España, Pop con Ñ y PEGAO.
#
# Apunte: las playlist elegidas son las principales que incluyen temas actuales, no necesariamente las que más seguidores tienen. Muchas de las listas más seguidas como 'Míticas' o 'Los 2000 en España' cuentan con temas antiguos que no tienen relación con las listas de éxitos actuales y el estado de la industria musical.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Configura las credenciales de la API de Spotify
client_id = '40855ddf3bd54d9d9c01b10b8bbf8fe8'
client_secret = 'd299e678564846c08fba7227c787e7c8'
redirect_uri = 'https://github.com/andrewgimeno/hundirlaflota'

# Autenticación
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Obtiene los datos de la lista de reproducción
playlist_id = '37i9dQZF1DXaxEKcoCdWHD'
results = sp.playlist(playlist_id)

# Procesa los datos
tracks = results['tracks']['items']
playlist_data = []
for track in tracks:
    album = track['track']['album']
    track_data = {
        'Track Name': track['track']['name'],
        'Artist': track['track']['artists'][0]['name'],
        'Album': album['name'],
        'Release Date': album['release_date'],
        'Label': ''
    }

# Obtener información adicional del sello discográfico
    album_details = sp.album(album['id'])
    if 'label' in album_details:
        track_data['Label'] = album_details['label']
    playlist_data.append(track_data)

# Crea un DataFrame
df = pd.DataFrame(playlist_data)

# Exporta el DataFrame a un archivo CSV
df.to_csv('exitos_españa.csv', index=False)

# %%
df_exitos_esp = pd.read_csv('exitos_españa.csv')

df_exitos_esp
# Out:
#                                 Track Name            Artist
# 0                           WHERE SHE GOES         Bad Bunny  \
# 1                                 Clavaito            Chanel
# 2                                Supernova             Saiko
# 3                                Acróstico           Shakira
# 4                                 EL TONTO       Lola Indigo
# 5                              Arena y Sal       Omar Montes
# 6                             Todo Contigo    Álvaro De Luna
# 7                               Nochentera             Vicco
# 8                                VAGABUNDO   Sebastian Yatra
# 9                         Que te vaya bien              Rvfv
# 10                         La Bebe - Remix         Yng Lvcas
# 11               Si La Calle Llama - Remix    Eladio Carrion
# 12                             Niña Bonita              Feid
# 13                               T'as peur      Aya Nakamura
# 14                                  Tattoo            Loreen
# 15                             El Merengue        Marshmello
# 16                   Flow Violento - Remix         YoSoyPlex
# 17                              Mami Chula            Jhayco
# 18                               La Fiesta        Pedro Capó
# 19                              Classy 101              Feid
# 20                                 Andando             Morad
# 21                                   Antes              Rvfv
# 22                   Arranca (feat. Omega)           Becky G
# 23                         Ella Baila Sola    Eslabon Armado
# 24                             Coco Chanel    Eladio Carrion
# 25                                      69         Nicky Jam
# 26                                Rara Vez              Taiu
# 27                 No Estuviste En Lo Malo             Morad
# 28                        PLAYA DEL INGLÉS           Quevedo
# 29                             DISPARA ***      Nicki Nicole
# 30                                 Polaris             Saiko
# 31                       Las Bratz (Remix)             Aissa
# 32                                    BESO           ROSALÍA
# 33                             Los Ángeles            Aitana
# 34                           Mi Nena Remix  Maikel Delacalle
# 35                 Pacto (feat. Luar La L)       Jay Wheeler
# 36                         REMIX EXCLUSIVO              Feid
# 37                               un x100to    Grupo Frontera
# 38                              Yandel 150            Yandel
# 39                                  Cupido              TINI
# 40                             Coti x Coti         The Tyets
# 41                  CHORRITO PA LAS ANIMAS              Feid
# 42                                AMARGURA           KAROL G
# 43                                 PUNTO G           Quevedo
# 44                                  MERCHO          LiL CaKe
# 45                                   WANDA           Quevedo
# 46                                     APA              Mora
# 47                                VAMPIROS           ROSALÍA
# 48                                MEMORIAS              Mora
# 49  Estrecho / Alvarado (feat. pablopablo)        C. Tangana
#
#                                      Album Release Date
# 0                           WHERE SHE GOES   2023-05-18  \
# 1                                 Clavaito   2023-04-27
# 2                                Supernova   2023-04-19
# 3                                Acróstico   2023-05-11
# 4                                EL DRAGÓN   2023-04-13
# 5                              Arena y Sal   2023-05-18
# 6                             Todo Contigo   2023-03-17
# 7                               Nochentera   2022-12-19
# 8                                VAGABUNDO   2023-05-12
# 9                         Que te vaya bien   2023-04-21
# 10                         La Bebe (Remix)   2023-03-17
# 11                              3MEN2 KBRN   2023-03-17
# 12                             Niña Bonita   2023-04-21
# 13                               T'as peur   2023-01-25
# 14                                  Tattoo   2023-02-25
# 15                             El Merengue   2023-03-03
# 16                   Flow Violento (Remix)   2023-01-13
# 17                              Mami Chula   2023-04-28
# 18                                 La Neta   2022-12-02
# 19                              Classy 101   2023-03-31
# 20                             Reinsertado   2023-05-12
# 21                                   Antes   2023-03-10
# 22                   Arranca (feat. Omega)   2023-03-10
# 23                         Ella Baila Sola   2023-03-16
# 24                              3MEN2 KBRN   2023-03-17
# 25                                      69   2023-05-19
# 26                                Rara Vez   2023-02-08
# 27                             Reinsertado   2023-05-12
# 28                      DONDE QUIERO ESTAR   2023-01-20
# 29                             DISPARA ***   2023-05-17
# 30                                 1371 KM   2022-08-26
# 31                       Las Bratz (Remix)   2023-03-08
# 32                                      RR   2023-03-24
# 33                             Los Ángeles   2023-03-29
# 34                           Mi Nena Remix   2023-03-23
# 35                 Pacto (feat. Luar La L)   2023-04-24
# 36                         REMIX EXCLUSIVO   2023-03-17
# 37                               un x100to   2023-04-17
# 38                              Yandel 150   2022-12-20
# 39                                  Cupido   2023-02-14
# 40                             Coti x Coti   2023-02-17
# 41                                   SIXDO   2022-12-02
# 42                      MAÑANA SERÁ BONITO   2023-02-24
# 43                      DONDE QUIERO ESTAR   2023-01-20
# 44                                  MERCHO   2022-12-16
# 45                      DONDE QUIERO ESTAR   2023-01-20
# 46                                 PARAÍSO   2022-11-03
# 47                                      RR   2023-03-24
# 48                              MICRODOSIS   2022-04-01
# 49  Estrecho / Alvarado (feat. pablopablo)   2023-05-05
#
#                                                 Label
# 0                             Rimas Entertainment LLC
# 1                            Sony Music Entertainment
# 2                                          2023 SAIKO
# 3                                    Sony Music Latin
# 4                          Universal Music Spain S.L.
# 5                                    Sony Music Latin
# 6                                            WM Spain
# 7                            Sony Music Entertainment
# 8                                       UMLE - Latino
# 9                                         NASTU MUSIC
# 10                                          WM Mexico
# 11                            Rimas Entertainment LLC
# 12                                      UMLE - Latino
# 13                                           Rec. 118
# 14                                 Universal Music AB
# 15                                   Sony Music Latin
# 16                                         Plex Music
# 17                              N&E Entertainment LLC
# 18                                   Sony Music Latin
# 19                                      UMLE - Latino
# 20                                            M.D.L.R
# 21                                        NASTU MUSIC
# 22                       Kemosabe Records/RCA Records
# 23                                        DEL Records
# 24                            Rimas Entertainment LLC
# 25                                   Sony Music Latin
# 26                     Universal Music Argentina S.A.
# 27                                            M.D.L.R
# 28                                            Quevedo
# 29                 Sony Music Latin/DALE PLAY Records
# 30                                         2022 Saiko
# 31                               Aissa el Aslani Erra
# 32  Columbia Records/Duars Entertainment/Sony Musi...
# 33                         Universal Music Spain S.L.
# 34                         Universal Music Spain S.L.
# 35            Linked Music / Dynamic Records / EMPIRE
# 36                                      UMLE - Latino
# 37                           Rimas Entertainment LLC.
# 38                                     La Leyenda LLC
# 39                                       5020 Records
# 40                                       Luup Records
# 41                                      UMLE - Latino
# 42                                      UMLE - Latino
# 43                                            Quevedo
# 44                               Sony Music Argentina
# 45                                            Quevedo
# 46                            Rimas Entertainment LLC
# 47  Columbia Records/Duars Entertainment/Sony Musi...
# 48                            Rimas Entertainment LLC
# 49                           Sony Music Entertainment

# %%
df_exitos_esp ['Label'] = df_exitos_esp ['Label'].replace({'Sony Music Entertainment': 'Sony Music', 'Sony Music Latin': 'Sony Music', 'Columbia Records/Duars Entertainment/Sony Musi...': 'Sony Music', 'Sony Music Latin/DALE PLAY Records': 'Sony Music','Sony Music Argentina':'Sony Music'})
df_exitos_esp['Label'] = df_exitos_esp ['Label'].replace({'WM Spain' : 'Warner Music', 'WM Mexico': 'Warner Music', 'WEA Latina' : 'Warner Music'})
df_exitos_esp ['Label'] = df_exitos_esp ['Label'].replace({'UMLE - Latino' : 'Universal Music', 'Universal Music Spain S.L.' : 'Universal Music', 'Virgin Music Spain': 'Universal Music','Universal Music Argentina S.A.': 'Universal Music', 'Universal Music AB': 'Universal Music'})

frecuencias = df_exitos_esp ['Label'].value_counts()
valores_unicos = frecuencias[frecuencias == 1].index
df_exitos_esp.loc[df_exitos_esp['Label'].isin(valores_unicos), 'Label'] = 'Otros'

porcentajes = df_exitos_esp['Label'].value_counts(normalize=True) * 100
valores = porcentajes.values
etiquetas = porcentajes.index
plt.pie(valores, labels=etiquetas, autopct='%1.1f%%')
plt.show()

# %%
# Obtiene los datos de la lista de reproducción
playlist_id = '37i9dQZF1DX3sCT1ItXgNd'
results = sp.playlist(playlist_id)

# Procesa los datos
tracks = results['tracks']['items']
playlist_data = []
for track in tracks:
    album = track['track']['album']
    track_data = {
        'Track Name': track['track']['name'],
        'Artist': track['track']['artists'][0]['name'],
        'Album': album['name'],
        'Release Date': album['release_date'],
        'Label': ''
    }

# Obtener información adicional del sello discográfico
    album_details = sp.album(album['id'])
    if 'label' in album_details:
        track_data['Label'] = album_details['label']
    playlist_data.append(track_data)

# Crea un DataFrame
df = pd.DataFrame(playlist_data)

# Exporta el DataFrame a un archivo CSV
df.to_csv('pop_con_ñ.csv', index=False)

# %%
df_pop_con_ñ = pd.read_csv('pop_con_ñ.csv')

df_pop_con_ñ.head(10)
# Out:
#         Track Name           Artist            Album Release Date
# 0        Acróstico          Shakira        Acróstico   2023-05-11  \
# 1        VAGABUNDO  Sebastian Yatra        VAGABUNDO   2023-05-12
# 2         Clavaito           Chanel         Clavaito   2023-04-27
# 3  Algo Sencillito     Marta Santos  Algo Sencillito   2023-05-18
# 4     Todo Contigo   Álvaro De Luna     Todo Contigo   2023-03-17
# 5         EL TONTO      Lola Indigo        EL DRAGÓN   2023-04-13
# 6      Coti x Coti        The Tyets      Coti x Coti   2023-02-17
# 7        La Fiesta       Pedro Capó        La Fiesta   2022-04-29
# 8      El Merengue       Marshmello      El Merengue   2023-03-03
# 9             P.M.           Chanel             P.M.   2023-05-19
#
#                         Label
# 0            Sony Music Latin
# 1               UMLE - Latino
# 2    Sony Music Entertainment
# 3          Virgin Music Spain
# 4                    WM Spain
# 5  Universal Music Spain S.L.
# 6                Luup Records
# 7            Sony Music Latin
# 8            Sony Music Latin
# 9    Sony Music Entertainment

# %%
df_pop_con_ñ ['Label'] = df_pop_con_ñ ['Label'].replace({'Sony Music Entertainment': 'Sony Music', 'Sony Music Latin': 'Sony Music'})
df_pop_con_ñ['Label'] = df_pop_con_ñ ['Label'].replace({'WM Spain' : 'Warner Music', 'WM Mexico': 'Warner Music', 'WEA Latina' : 'Warner Music'})
df_pop_con_ñ ['Label'] = df_pop_con_ñ ['Label'].replace({'UMLE - Latino' : 'Universal Music', 'Universal Music Spain S.L.' : 'Universal Music', 'Virgin Music Spain': 'Universal Music'})

frecuencias = df_pop_con_ñ ['Label'].value_counts()
valores_unicos = frecuencias[frecuencias == 1].index
df_pop_con_ñ.loc[df_pop_con_ñ['Label'].isin(valores_unicos), 'Label'] = 'Otros'

porcentajes = df_pop_con_ñ['Label'].value_counts(normalize=True) * 100
valores = porcentajes.values
etiquetas = porcentajes.index
plt.pie(valores, labels=etiquetas, autopct='%1.1f%%')
plt.show()

# %%
# Obtiene los datos de la lista de reproducción
playlist_id = '37i9dQZF1DX1HCSfq0nSal'
results = sp.playlist(playlist_id)

# Procesa los datos
tracks = results['tracks']['items']
playlist_data = []
for track in tracks:
    album = track['track']['album']
    track_data = {
        'Track Name': track['track']['name'],
        'Artist': track['track']['artists'][0]['name'],
        'Album': album['name'],
        'Release Date': album['release_date'],
        'Label': ''
    }

# Obtener información adicional del sello discográfico
    album_details = sp.album(album['id'])
    if 'label' in album_details:
        track_data['Label'] = album_details['label']
    playlist_data.append(track_data)

# Crea un DataFrame
df = pd.DataFrame(playlist_data)

# Exporta el DataFrame a un archivo CSV
df.to_csv('pegao.csv', index=False)

# %%
df_pegao = pd.read_csv('pegao.csv')

df_pegao.head(10)
# Out:
#                 Track Name       Artist                    Album Release Date
# 0           WHERE SHE GOES    Bad Bunny           WHERE SHE GOES   2023-05-18  \
# 1  Pacto (feat. Luar La L)  Jay Wheeler  Pacto (feat. Luar La L)   2023-04-24
# 2                       69    Nicky Jam                       69   2023-05-19
# 3     Corazón Roto - Remix        Brray     Corazón Roto (Remix)   2023-04-07
# 4              Arena y Sal  Omar Montes              Arena y Sal   2023-05-18
# 5               Mami Chula       Jhayco               Mami Chula   2023-04-28
# 6   QUE RICO (w/ Bad Gyal)    Un Titico   QUE RICO (w/ Bad Gyal)   2023-05-18
# 7                Supernova        Saiko                Supernova   2023-04-19
# 8         Que te vaya bien         Rvfv         Que te vaya bien   2023-04-21
# 9                  Andando        Morad              Reinsertado   2023-05-12
#
#                                                Label
# 0                            Rimas Entertainment LLC
# 1            Linked Music / Dynamic Records / EMPIRE
# 2                                   Sony Music Latin
# 3                                      UMLE - Latino
# 4                                   Sony Music Latin
# 5                              N&E Entertainment LLC
# 6  2023 Calientalo Media / WK Records / Bad Gyal,...
# 7                                         2023 SAIKO
# 8                                        NASTU MUSIC
# 9                                            M.D.L.R

# %%
df_sorted_pegao = df_pegao.sort_values('Label')

df_sorted_pegao
# Out:
#                    Track Name            Artist                    Album
# 11              Tú No Lo Amas          Anuel AA     Real Hasta la Muerte  \
# 41                    Piensan       Myke Towers          Easy Money Baby
# 45                    Polaris             Saiko                  1371 KM
# 6      QUE RICO (w/ Bad Gyal)         Un Titico   QUE RICO (w/ Bad Gyal)
# 43                     Sikora             Saiko                   Sikora
# 7                   Supernova             Saiko                Supernova
# 34          Las Bratz (Remix)             Aissa        Las Bratz (Remix)
# 28                M.A - Remix                BM              M.A (Remix)
# 14                    Amanece          Anuel AA                  Amanece
# 24            Sígueme - Remix              Feid          Sígueme (Remix)
# 42                   D X VIDA             Alejo                 D X VIDA
# 49                 Yandel 150            Yandel               Yandel 150
# 1     Pacto (feat. Luar La L)       Jay Wheeler  Pacto (feat. Luar La L)
# 35                QUÉSESIENTE          Lucho RK              QUÉSESIENTE
# 9                     Andando             Morad              Reinsertado
# 15                     4 PREZ       Cruz Cafuné                   4 PREZ
# 5                  Mami Chula            Jhayco               Mami Chula
# 26                 Cuerpecito            Jhayco               Cuerpecito
# 8            Que te vaya bien              Rvfv         Que te vaya bien
# 25                      Antes              Rvfv                    Antes
# 19                   2 Hielos      King Savagge                 2 Hielos
# 44                       DAME           Quevedo       DONDE QUIERO ESTAR
# 48                      WANDA           Quevedo       DONDE QUIERO ESTAR
# 13             Tuenti - Remix        Raul Clyde           Tuenti (Remix)
# 12  Si La Calle Llama - Remix    Eladio Carrion               3MEN2 KBRN
# 38            DOMINGO DE BOTE              Mora                  PARAÍSO
# 27                Coco Chanel    Eladio Carrion               3MEN2 KBRN
# 30              Triste Verano    Eladio Carrion            Triste Verano
# 0              WHERE SHE GOES         Bad Bunny           WHERE SHE GOES
# 16                       3 Am    Eladio Carrion               Sauce Boyz
# 20                     RÁPIDO              Mora                   RÁPIDO
# 33             Una Noche Loca           Nickzzy           Una Noche Loca
# 2                          69         Nicky Jam                       69
# 4                 Arena y Sal       Omar Montes              Arena y Sal
# 22              Un Cigarrillo  Chencho Corleone            Un Cigarrillo
# 32       qué le pasa conmigo?      Nicki Nicole     qué le pasa conmigo?
# 39                   Mxfix G5              Feid                 Mxfix G5
# 3        Corazón Roto - Remix             Brray     Corazón Roto (Remix)
# 10                 Classy 101              Feid               Classy 101
# 46            REMIX EXCLUSIVO              Feid          REMIX EXCLUSIVO
# 47     CHORRITO PA LAS ANIMAS              Feid                    SIXDO
# 18                Niña Bonita              Feid              Niña Bonita
# 31            Cosas Locas 2.0      Danny Romero          Cosas Locas 2.0
# 29              Mi Nena Remix  Maikel Delacalle            Mi Nena Remix
# 36                   MI DROGA       Myke Towers           LA VIDA ES UNA
# 23             Whiskey y Coco     Justin Quiles           Whiskey y Coco
# 40                  En Bajita     Justin Quiles                En Bajita
# 17                     VOODOO       Myke Towers           LA VIDA ES UNA
# 21            La Bebe - Remix         Yng Lvcas          La Bebe (Remix)
# 37             UNA ÚLTIMA VEZ      Soge Culebra           UNA ÚLTIMA VEZ
#
#    Release Date                                              Label
# 11   2018-07-17                    2018 Real Hasta La Muerte, Inc.
# 41   2020-01-24  2020 One World Music & Casablanca Records | Po...
# 45   2022-08-26                                         2022 Saiko
# 6    2023-05-18  2023 Calientalo Media / WK Records / Bad Gyal,...
# 43   2023-02-10                                         2023 SAIKO
# 7    2023-04-19                                         2023 SAIKO
# 34   2023-03-08                               Aissa el Aslani Erra
# 28   2023-04-05              DALE PLAY Records / Wesaisons Records
# 14   2018-12-14                                      House of Haze
# 24   2019-02-01                      JP Entertainment (Jorge Pino)
# 42   2023-03-30                                              Jungl
# 49   2022-12-20                                     La Leyenda LLC
# 1    2023-04-24            Linked Music / Dynamic Records / EMPIRE
# 35   2023-01-27                                           Lucho RK
# 9    2023-05-12                                            M.D.L.R
# 15   2023-05-11                                         MÉCÈN Ent.
# 5    2023-04-28                              N&E Entertainment LLC
# 26   2023-03-31                              N&E Entertainment LLC
# 8    2023-04-21                                        NASTU MUSIC
# 25   2023-03-10                                        NASTU MUSIC
# 19   2023-02-02                                  Nabru Records LLC
# 44   2023-01-20                                            Quevedo
# 48   2023-01-20                                            Quevedo
# 13   2022-12-14                                 Raul Clyde x Saiko
# 12   2023-03-17                            Rimas Entertainment LLC
# 38   2022-11-03                            Rimas Entertainment LLC
# 27   2023-03-17                            Rimas Entertainment LLC
# 30   2023-04-14                            Rimas Entertainment LLC
# 0    2023-05-18                            Rimas Entertainment LLC
# 16   2020-01-31                            Rimas Entertainment LLC
# 20   2023-04-27                            Rimas Entertainment LLC
# 33   2023-05-11                           Sony Music Entertainment
# 2    2023-05-19                                   Sony Music Latin
# 4    2023-05-18                                   Sony Music Latin
# 22   2023-05-04                                   Sony Music Latin
# 32   2023-04-19                 Sony Music Latin/DALE PLAY Records
# 39   2023-05-12                                      UMLE - Latino
# 3    2023-04-07                                      UMLE - Latino
# 10   2023-03-31                                      UMLE - Latino
# 46   2023-03-17                                      UMLE - Latino
# 47   2022-12-02                                      UMLE - Latino
# 18   2023-04-21                                      UMLE - Latino
# 31   2023-03-16                         Universal Music Spain S.L.
# 29   2023-03-23                         Universal Music Spain S.L.
# 36   2023-03-23                                         WEA Latina
# 23   2023-01-12                                         WEA Latina
# 40   2023-03-16                                         WEA Latina
# 17   2023-03-23                                         WEA Latina
# 21   2023-03-17                                          WM Mexico
# 37   2023-04-14                                           WM Spain

# %%
# Vamos a cambiar los nombres regionales de los sellos para poder agruparlos (por ejemplo: WM Spain, WM Mexico y WEA Latina = Warner Music)

df_sorted_pegao ['Label'] = df_sorted_pegao ['Label'].replace({'Sony Music Entertainment': 'Sony Music'})
df_sorted_pegao ['Label'] = df_sorted_pegao ['Label'].replace({'WM Spain' : 'Warner Music', 'WM Mexico': 'Warner Music', 'WEA Latina' : 'Warner Music'})
df_sorted_pegao ['Label'] = df_sorted_pegao ['Label'].replace({'UMLE - Latino' : 'Universal Music', 'Universal Music Spain S.L.' : 'Universal Music'})

# %%
# Para que la representación gráfica del dataframe quede más limpia, 
# vamos a sustituir todos los valores que no están repetidos (todos ellos ellos y distribuidoras independientes) por el valor 'Otros'

frecuencias = df_sorted_pegao ['Label'].value_counts()

valores_unicos = frecuencias[frecuencias == 1].index

df_sorted_pegao.loc[df_sorted_pegao['Label'].isin(valores_unicos), 'Label'] = 'Otros'

df_sorted_pegao
# Out:
#                    Track Name            Artist                    Album
# 11              Tú No Lo Amas          Anuel AA     Real Hasta la Muerte  \
# 41                    Piensan       Myke Towers          Easy Money Baby
# 45                    Polaris             Saiko                  1371 KM
# 6      QUE RICO (w/ Bad Gyal)         Un Titico   QUE RICO (w/ Bad Gyal)
# 43                     Sikora             Saiko                   Sikora
# 7                   Supernova             Saiko                Supernova
# 34          Las Bratz (Remix)             Aissa        Las Bratz (Remix)
# 28                M.A - Remix                BM              M.A (Remix)
# 14                    Amanece          Anuel AA                  Amanece
# 24            Sígueme - Remix              Feid          Sígueme (Remix)
# 42                   D X VIDA             Alejo                 D X VIDA
# 49                 Yandel 150            Yandel               Yandel 150
# 1     Pacto (feat. Luar La L)       Jay Wheeler  Pacto (feat. Luar La L)
# 35                QUÉSESIENTE          Lucho RK              QUÉSESIENTE
# 9                     Andando             Morad              Reinsertado
# 15                     4 PREZ       Cruz Cafuné                   4 PREZ
# 5                  Mami Chula            Jhayco               Mami Chula
# 26                 Cuerpecito            Jhayco               Cuerpecito
# 8            Que te vaya bien              Rvfv         Que te vaya bien
# 25                      Antes              Rvfv                    Antes
# 19                   2 Hielos      King Savagge                 2 Hielos
# 44                       DAME           Quevedo       DONDE QUIERO ESTAR
# 48                      WANDA           Quevedo       DONDE QUIERO ESTAR
# 13             Tuenti - Remix        Raul Clyde           Tuenti (Remix)
# 12  Si La Calle Llama - Remix    Eladio Carrion               3MEN2 KBRN
# 38            DOMINGO DE BOTE              Mora                  PARAÍSO
# 27                Coco Chanel    Eladio Carrion               3MEN2 KBRN
# 30              Triste Verano    Eladio Carrion            Triste Verano
# 0              WHERE SHE GOES         Bad Bunny           WHERE SHE GOES
# 16                       3 Am    Eladio Carrion               Sauce Boyz
# 20                     RÁPIDO              Mora                   RÁPIDO
# 33             Una Noche Loca           Nickzzy           Una Noche Loca
# 2                          69         Nicky Jam                       69
# 4                 Arena y Sal       Omar Montes              Arena y Sal
# 22              Un Cigarrillo  Chencho Corleone            Un Cigarrillo
# 32       qué le pasa conmigo?      Nicki Nicole     qué le pasa conmigo?
# 39                   Mxfix G5              Feid                 Mxfix G5
# 3        Corazón Roto - Remix             Brray     Corazón Roto (Remix)
# 10                 Classy 101              Feid               Classy 101
# 46            REMIX EXCLUSIVO              Feid          REMIX EXCLUSIVO
# 47     CHORRITO PA LAS ANIMAS              Feid                    SIXDO
# 18                Niña Bonita              Feid              Niña Bonita
# 31            Cosas Locas 2.0      Danny Romero          Cosas Locas 2.0
# 29              Mi Nena Remix  Maikel Delacalle            Mi Nena Remix
# 36                   MI DROGA       Myke Towers           LA VIDA ES UNA
# 23             Whiskey y Coco     Justin Quiles           Whiskey y Coco
# 40                  En Bajita     Justin Quiles                En Bajita
# 17                     VOODOO       Myke Towers           LA VIDA ES UNA
# 21            La Bebe - Remix         Yng Lvcas          La Bebe (Remix)
# 37             UNA ÚLTIMA VEZ      Soge Culebra           UNA ÚLTIMA VEZ
#
#    Release Date                    Label
# 11   2018-07-17                    Otros
# 41   2020-01-24                    Otros
# 45   2022-08-26                    Otros
# 6    2023-05-18                    Otros
# 43   2023-02-10               2023 SAIKO
# 7    2023-04-19               2023 SAIKO
# 34   2023-03-08                    Otros
# 28   2023-04-05                    Otros
# 14   2018-12-14                    Otros
# 24   2019-02-01                    Otros
# 42   2023-03-30                    Otros
# 49   2022-12-20                    Otros
# 1    2023-04-24                    Otros
# 35   2023-01-27                    Otros
# 9    2023-05-12                    Otros
# 15   2023-05-11                    Otros
# 5    2023-04-28    N&E Entertainment LLC
# 26   2023-03-31    N&E Entertainment LLC
# 8    2023-04-21              NASTU MUSIC
# 25   2023-03-10              NASTU MUSIC
# 19   2023-02-02                    Otros
# 44   2023-01-20                  Quevedo
# 48   2023-01-20                  Quevedo
# 13   2022-12-14                    Otros
# 12   2023-03-17  Rimas Entertainment LLC
# 38   2022-11-03  Rimas Entertainment LLC
# 27   2023-03-17  Rimas Entertainment LLC
# 30   2023-04-14  Rimas Entertainment LLC
# 0    2023-05-18  Rimas Entertainment LLC
# 16   2020-01-31  Rimas Entertainment LLC
# 20   2023-04-27  Rimas Entertainment LLC
# 33   2023-05-11               Sony Music
# 2    2023-05-19               Sony Music
# 4    2023-05-18               Sony Music
# 22   2023-05-04               Sony Music
# 32   2023-04-19               Sony Music
# 39   2023-05-12          Universal Music
# 3    2023-04-07          Universal Music
# 10   2023-03-31          Universal Music
# 46   2023-03-17          Universal Music
# 47   2022-12-02          Universal Music
# 18   2023-04-21          Universal Music
# 31   2023-03-16          Universal Music
# 29   2023-03-23          Universal Music
# 36   2023-03-23             Warner Music
# 23   2023-01-12             Warner Music
# 40   2023-03-16             Warner Music
# 17   2023-03-23             Warner Music
# 21   2023-03-17             Warner Music
# 37   2023-04-14             Warner Music

# %%
porcentajes = df_sorted_pegao['Label'].value_counts(normalize=True) * 100

valores = porcentajes.values
etiquetas = porcentajes.index

plt.pie(valores, labels=etiquetas, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Continuamos visualizando las principales playlist editoriales internacionales: La Lista Pop, Today's Top Hits, RapCaviar (playlist temática con más seguidores: 15M).

# %%
# Obtiene los datos de la lista de reproducción
playlist_id = '37i9dQZF1DWSpF87bP6JSF'
results = sp.playlist(playlist_id)

# Procesa los datos
tracks = results['tracks']['items']
playlist_data = []
for track in tracks:
    album = track['track']['album']
    track_data = {
        'Track Name': track['track']['name'],
        'Artist': track['track']['artists'][0]['name'],
        'Album': album['name'],
        'Release Date': album['release_date'],
        'Label': ''
    }

# Obtener información adicional del sello discográfico
    album_details = sp.album(album['id'])
    if 'label' in album_details:
        track_data['Label'] = album_details['label']
    playlist_data.append(track_data)

# Crea un DataFrame
df = pd.DataFrame(playlist_data)

# Exporta el DataFrame a un archivo CSV
df.to_csv('la_lista_pop.csv', index=False)

# %%
df_la_lista_pop = pd.read_csv('la_lista_pop.csv')

df_la_lista_pop.head(10)
# Out:
#                   Track Name           Artist                  Album
# 0                  un x100to   Grupo Frontera              un x100to  \
# 1                El Merengue       Marshmello            El Merengue
# 2                  Acróstico          Shakira              Acróstico
# 3                       BESO          ROSALÍA                     RR
# 4             WHERE SHE GOES        Bad Bunny         WHERE SHE GOES
# 5  MIENTRAS ME CURO DEL CORA          KAROL G     MAÑANA SERÁ BONITO
# 6                  VAGABUNDO  Sebastian Yatra              VAGABUNDO
# 7                         69        Nicky Jam                     69
# 8                     1Trago      Danna Paola                 1Trago
# 9      Arranca (feat. Omega)          Becky G  Arranca (feat. Omega)
#
#   Release Date                                              Label
# 0   2023-04-17                           Rimas Entertainment LLC.
# 1   2023-03-03                                   Sony Music Latin
# 2   2023-05-11                                   Sony Music Latin
# 3   2023-03-24  Columbia Records/Duars Entertainment/Sony Musi...
# 4   2023-05-18                            Rimas Entertainment LLC
# 5   2023-02-24                                      UMLE - Latino
# 6   2023-05-12                                      UMLE - Latino
# 7   2023-05-19                                   Sony Music Latin
# 8   2023-04-14                             Universal Music Mexico
# 9   2023-03-10                       Kemosabe Records/RCA Records

# %%
df_la_lista_pop ['Label'] = df_la_lista_pop ['Label'].replace({'Sony Music Entertainment': 'Sony Music', 'Sony Music Latin': 'Sony Music', 'Columbia Records/Duars Entertainment/Sony Musi...': 'Sony Music', 'Sony Music Latin/DALE PLAY Records': 'Sony Music','Sony Music Argentina':'Sony Music','Sony Music Latin/Duars Entertainment':'Sony Music','Columbia':'Sony Music', 'Columbia Records/Duars Entertainment/Sony Music Latin': 'Sony Music'})
df_la_lista_pop['Label'] = df_la_lista_pop ['Label'].replace({'WM Spain' : 'Warner Music', 'WM Mexico': 'Warner Music', 'WEA Latina' : 'Warner Music','WM Korea':'Warner Music'})
df_la_lista_pop ['Label'] = df_la_lista_pop ['Label'].replace({'UMLE - Latino' : 'Universal Music', 'Universal Music Spain S.L.' : 'Universal Music', 'Virgin Music Spain': 'Universal Music','Universal Music Argentina S.A.': 'Universal Music', 'Universal Music AB': 'Universal Music', 'Republic Records':'Universal Music','Universal Republic Records':'Universal Music','Universal-Island Records Ltd.':'Universal Msuic', 'Universal Music Mexico': 'Universal Music'})

frecuencias = df_la_lista_pop ['Label'].value_counts()
valores_unicos = frecuencias[frecuencias == 1].index
df_la_lista_pop.loc[df_la_lista_pop['Label'].isin(valores_unicos), 'Label'] = 'Otros'

porcentajes = df_la_lista_pop['Label'].value_counts(normalize=True) * 100
valores = porcentajes.values
etiquetas = porcentajes.index
plt.pie(valores, labels=etiquetas, autopct='%1.1f%%')
plt.show()

# %%
# Obtiene los datos de la lista de reproducción
playlist_id = '37i9dQZF1DXcBWIGoYBM5M'
results = sp.playlist(playlist_id)

# Procesa los datos
tracks = results['tracks']['items']
playlist_data = []
for track in tracks:
    album = track['track']['album']
    track_data = {
        'Track Name': track['track']['name'],
        'Artist': track['track']['artists'][0]['name'],
        'Album': album['name'],
        'Release Date': album['release_date'],
        'Label': ''
    }

# Obtener información adicional del sello discográfico
    album_details = sp.album(album['id'])
    if 'label' in album_details:
        track_data['Label'] = album_details['label']
    playlist_data.append(track_data)

# Crea un DataFrame
df = pd.DataFrame(playlist_data)

# Exporta el DataFrame a un archivo CSV
df.to_csv('todays_top_hits.csv', index=False)

# %%
df_todays_top_hits = pd.read_csv('todays_top_hits.csv')

df_todays_top_hits.head(10)
# Out:
#                                      Track Name          Artist
# 0                                WHERE SHE GOES       Bad Bunny  \
# 1                                     Kill Bill             SZA
# 2                 Calm Down (with Selena Gomez)            Rema
# 3                                       Flowers     Miley Cyrus
# 4  AMERICA HAS A PROBLEM (feat. Kendrick Lamar)         Beyoncé
# 5                            Boy's a Liar Pt. 2  PinkPantheress
# 6                             Cupid - Twin Ver.     FIFTY FIFTY
# 7                           Die For You - Remix      The Weeknd
# 8                                     As It Was    Harry Styles
# 9                                      Daylight   David Kushner
#
#                                           Album Release Date
# 0                                WHERE SHE GOES   2023-05-18  \
# 1                                           SOS   2022-12-08
# 2                 Calm Down (with Selena Gomez)   2022-08-25
# 3                                       Flowers   2023-01-13
# 4  AMERICA HAS A PROBLEM (feat. Kendrick Lamar)   2023-05-19
# 5                            Boy's a liar Pt. 2   2023-02-03
# 6                          The Beginning: Cupid   2023-02-24
# 7                           Die For You (Remix)   2023-02-24
# 8                                     As It Was   2022-03-31
# 9                                      Daylight   2023-04-14
#
#                                 Label
# 0             Rimas Entertainment LLC
# 1  Top Dawg Entertainment/RCA Records
# 2       Mavin Records / Jonzing World
# 3                            Columbia
# 4     Parkwood Entertainment/Columbia
# 5                      Warner Records
# 6                            WM Korea
# 7               XO / Republic Records
# 8                            Columbia
# 9          Miserable Music Group, LLC

# %%
df_todays_top_hits ['Label'] = df_todays_top_hits ['Label'].replace({'Sony Music Entertainment': 'Sony Music', 'Sony Music Latin': 'Sony Music', 'Columbia Records/Duars Entertainment/Sony Musi...': 'Sony Music', 'Sony Music Latin/DALE PLAY Records': 'Sony Music','Sony Music Argentina':'Sony Music','Sony Music Latin/Duars Entertainment':'Sony Music','Columbia':'Sony Music', 'Columbia Records/Duars Entertainment/Sony Music Latin': 'Sony Music'})
df_todays_top_hits['Label'] = df_todays_top_hits ['Label'].replace({'WM Spain' : 'Warner Music', 'WM Mexico': 'Warner Music', 'WEA Latina' : 'Warner Music','WM Korea':'Warner Music','Warner Records':'Warner Music'})
df_todays_top_hits ['Label'] = df_todays_top_hits ['Label'].replace({'UMLE - Latino' : 'Universal Music', 'Universal Music Spain S.L.' : 'Universal Music', 'Virgin Music Spain': 'Universal Music','Universal Music Argentina S.A.': 'Universal Music', 'Universal Music AB': 'Universal Music', 'Republic Records':'Universal Music','Universal Republic Records':'Universal Music','Universal-Island Records Ltd.':'Universal Msuic', 'Universal Music Mexico': 'Universal Music','XO / Republic Records':'Universal Music'})

frecuencias = df_todays_top_hits ['Label'].value_counts()
valores_unicos = frecuencias[frecuencias == 1].index
df_todays_top_hits.loc[df_todays_top_hits['Label'].isin(valores_unicos), 'Label'] = 'Otros'

porcentajes = df_todays_top_hits['Label'].value_counts(normalize=True) * 100
valores = porcentajes.values
etiquetas = porcentajes.index
plt.pie(valores, labels=etiquetas, autopct='%1.1f%%')
plt.show()

# %%
inter_esp_exitos = list(set(df_esp['Track Name'].tolist()) & set(df_exitos_esp['Track Name'].tolist()))

df_inter_esp_exitos = pd.DataFrame(inter_esp_exitos, columns=['Track Name'])

df_inter_esp_exitos

# De los 49 temas que hay en la playlist Éxitos España, 40 de ellos están en el top 200 de ventas.
# Out:
#                                 Track Name
# 0                                 Rara Vez
# 1   Estrecho / Alvarado (feat. pablopablo)
# 2                                T'as peur
# 3                                 Clavaito
# 4                              Los Ángeles
# 5                          REMIX EXCLUSIVO
# 6                Si La Calle Llama - Remix
# 7                                un x100to
# 8                              El Merengue
# 9                               Nochentera
# 10                            Todo Contigo
# 11                                 Polaris
# 12                         La Bebe - Remix
# 13                   Flow Violento - Remix
# 14                 Pacto (feat. Luar La L)
# 15                        PLAYA DEL INGLÉS
# 16                           Mi Nena Remix
# 17                   Arranca (feat. Omega)
# 18                                  Cupido
# 19                              Classy 101
# 20                        Que te vaya bien
# 21                                   WANDA
# 22                                     APA
# 23                                MEMORIAS
# 24                             Coco Chanel
# 25                               La Fiesta
# 26                       Las Bratz (Remix)
# 27                  CHORRITO PA LAS ANIMAS
# 28                                   Antes
# 29                               Supernova
# 30                         Ella Baila Sola
# 31                                 PUNTO G
# 32                                EL TONTO
# 33                                    BESO
# 34                                  MERCHO
# 35                                VAMPIROS
# 36                             Coti x Coti
# 37                             Niña Bonita
# 38                              Yandel 150
# 39                                AMARGURA
# 40                              Mami Chula

# %%
diferencia = df_exitos_esp.merge(df_esp, how='left', indicator=True)
diferencia = diferencia[diferencia['_merge'] == 'left_only']

diferencia
# Out:
#                  Track Name           Artist           Album Release Date
# 0            WHERE SHE GOES        Bad Bunny  WHERE SHE GOES   2023-05-18  \
# 3                 Acróstico          Shakira       Acróstico   2023-05-11
# 5               Arena y Sal      Omar Montes     Arena y Sal   2023-05-18
# 8                 VAGABUNDO  Sebastian Yatra       VAGABUNDO   2023-05-12
# 14                   Tattoo           Loreen          Tattoo   2023-02-25
# 20                  Andando            Morad     Reinsertado   2023-05-12
# 25                       69        Nicky Jam              69   2023-05-19
# 27  No Estuviste En Lo Malo            Morad     Reinsertado   2023-05-12
# 29              DISPARA ***     Nicki Nicole     DISPARA ***   2023-05-17
#
#                                  Label  rank artist_names  peak_rank
# 0              Rimas Entertainment LLC   NaN          NaN        NaN  \
# 3                     Sony Music Latin   NaN          NaN        NaN
# 5                     Sony Music Latin   NaN          NaN        NaN
# 8                        UMLE - Latino   NaN          NaN        NaN
# 14                  Universal Music AB   NaN          NaN        NaN
# 20                             M.D.L.R   NaN          NaN        NaN
# 25                    Sony Music Latin   NaN          NaN        NaN
# 27                             M.D.L.R   NaN          NaN        NaN
# 29  Sony Music Latin/DALE PLAY Records   NaN          NaN        NaN
#
#     previous_rank  weeks_on_chart  streams     _merge
# 0             NaN             NaN      NaN  left_only
# 3             NaN             NaN      NaN  left_only
# 5             NaN             NaN      NaN  left_only
# 8             NaN             NaN      NaN  left_only
# 14            NaN             NaN      NaN  left_only
# 20            NaN             NaN      NaN  left_only
# 25            NaN             NaN      NaN  left_only
# 27            NaN             NaN      NaN  left_only
# 29            NaN             NaN      NaN  left_only

# %%
df_exitos_esp.info
# Out:
# <bound method DataFrame.info of                                 Track Name            Artist
# 0                           WHERE SHE GOES         Bad Bunny  \
# 1                                 Clavaito            Chanel
# 2                                Supernova             Saiko
# 3                                Acróstico           Shakira
# 4                                 EL TONTO       Lola Indigo
# 5                              Arena y Sal       Omar Montes
# 6                             Todo Contigo    Álvaro De Luna
# 7                               Nochentera             Vicco
# 8                                VAGABUNDO   Sebastian Yatra
# 9                         Que te vaya bien              Rvfv
# 10                         La Bebe - Remix         Yng Lvcas
# 11               Si La Calle Llama - Remix    Eladio Carrion
# 12                             Niña Bonita              Feid
# 13                               T'as peur      Aya Nakamura
# 14                                  Tattoo            Loreen
# 15                             El Merengue        Marshmello
# 16                   Flow Violento - Remix         YoSoyPlex
# 17                              Mami Chula            Jhayco
# 18                               La Fiesta        Pedro Capó
# 19                              Classy 101              Feid
# 20                                 Andando             Morad
# 21                                   Antes              Rvfv
# 22                   Arranca (feat. Omega)           Becky G
# 23                         Ella Baila Sola    Eslabon Armado
# 24                             Coco Chanel    Eladio Carrion
# 25                                      69         Nicky Jam
# 26                                Rara Vez              Taiu
# 27                 No Estuviste En Lo Malo             Morad
# 28                        PLAYA DEL INGLÉS           Quevedo
# 29                             DISPARA ***      Nicki Nicole
# 30                                 Polaris             Saiko
# 31                       Las Bratz (Remix)             Aissa
# 32                                    BESO           ROSALÍA
# 33                             Los Ángeles            Aitana
# 34                           Mi Nena Remix  Maikel Delacalle
# 35                 Pacto (feat. Luar La L)       Jay Wheeler
# 36                         REMIX EXCLUSIVO              Feid
# 37                               un x100to    Grupo Frontera
# 38                              Yandel 150            Yandel
# 39                                  Cupido              TINI
# 40                             Coti x Coti         The Tyets
# 41                  CHORRITO PA LAS ANIMAS              Feid
# 42                                AMARGURA           KAROL G
# 43                                 PUNTO G           Quevedo
# 44                                  MERCHO          LiL CaKe
# 45                                   WANDA           Quevedo
# 46                                     APA              Mora
# 47                                VAMPIROS           ROSALÍA
# 48                                MEMORIAS              Mora
# 49  Estrecho / Alvarado (feat. pablopablo)        C. Tangana
#
#                                      Album Release Date
# 0                           WHERE SHE GOES   2023-05-18  \
# 1                                 Clavaito   2023-04-27
# 2                                Supernova   2023-04-19
# 3                                Acróstico   2023-05-11
# 4                                EL DRAGÓN   2023-04-13
# 5                              Arena y Sal   2023-05-18
# 6                             Todo Contigo   2023-03-17
# 7                               Nochentera   2022-12-19
# 8                                VAGABUNDO   2023-05-12
# 9                         Que te vaya bien   2023-04-21
# 10                         La Bebe (Remix)   2023-03-17
# 11                              3MEN2 KBRN   2023-03-17
# 12                             Niña Bonita   2023-04-21
# 13                               T'as peur   2023-01-25
# 14                                  Tattoo   2023-02-25
# 15                             El Merengue   2023-03-03
# 16                   Flow Violento (Remix)   2023-01-13
# 17                              Mami Chula   2023-04-28
# 18                                 La Neta   2022-12-02
# 19                              Classy 101   2023-03-31
# 20                             Reinsertado   2023-05-12
# 21                                   Antes   2023-03-10
# 22                   Arranca (feat. Omega)   2023-03-10
# 23                         Ella Baila Sola   2023-03-16
# 24                              3MEN2 KBRN   2023-03-17
# 25                                      69   2023-05-19
# 26                                Rara Vez   2023-02-08
# 27                             Reinsertado   2023-05-12
# 28                      DONDE QUIERO ESTAR   2023-01-20
# 29                             DISPARA ***   2023-05-17
# 30                                 1371 KM   2022-08-26
# 31                       Las Bratz (Remix)   2023-03-08
# 32                                      RR   2023-03-24
# 33                             Los Ángeles   2023-03-29
# 34                           Mi Nena Remix   2023-03-23
# 35                 Pacto (feat. Luar La L)   2023-04-24
# 36                         REMIX EXCLUSIVO   2023-03-17
# 37                               un x100to   2023-04-17
# 38                              Yandel 150   2022-12-20
# 39                                  Cupido   2023-02-14
# 40                             Coti x Coti   2023-02-17
# 41                                   SIXDO   2022-12-02
# 42                      MAÑANA SERÁ BONITO   2023-02-24
# 43                      DONDE QUIERO ESTAR   2023-01-20
# 44                                  MERCHO   2022-12-16
# 45                      DONDE QUIERO ESTAR   2023-01-20
# 46                                 PARAÍSO   2022-11-03
# 47                                      RR   2023-03-24
# 48                              MICRODOSIS   2022-04-01
# 49  Estrecho / Alvarado (feat. pablopablo)   2023-05-05
#
#                                                 Label
# 0                             Rimas Entertainment LLC
# 1                            Sony Music Entertainment
# 2                                          2023 SAIKO
# 3                                    Sony Music Latin
# 4                          Universal Music Spain S.L.
# 5                                    Sony Music Latin
# 6                                            WM Spain
# 7                            Sony Music Entertainment
# 8                                       UMLE - Latino
# 9                                         NASTU MUSIC
# 10                                          WM Mexico
# 11                            Rimas Entertainment LLC
# 12                                      UMLE - Latino
# 13                                           Rec. 118
# 14                                 Universal Music AB
# 15                                   Sony Music Latin
# 16                                         Plex Music
# 17                              N&E Entertainment LLC
# 18                                   Sony Music Latin
# 19                                      UMLE - Latino
# 20                                            M.D.L.R
# 21                                        NASTU MUSIC
# 22                       Kemosabe Records/RCA Records
# 23                                        DEL Records
# 24                            Rimas Entertainment LLC
# 25                                   Sony Music Latin
# 26                     Universal Music Argentina S.A.
# 27                                            M.D.L.R
# 28                                            Quevedo
# 29                 Sony Music Latin/DALE PLAY Records
# 30                                         2022 Saiko
# 31                               Aissa el Aslani Erra
# 32  Columbia Records/Duars Entertainment/Sony Musi...
# 33                         Universal Music Spain S.L.
# 34                         Universal Music Spain S.L.
# 35            Linked Music / Dynamic Records / EMPIRE
# 36                                      UMLE - Latino
# 37                           Rimas Entertainment LLC.
# 38                                     La Leyenda LLC
# 39                                       5020 Records
# 40                                       Luup Records
# 41                                      UMLE - Latino
# 42                                      UMLE - Latino
# 43                                            Quevedo
# 44                               Sony Music Argentina
# 45                                            Quevedo
# 46                            Rimas Entertainment LLC
# 47  Columbia Records/Duars Entertainment/Sony Musi...
# 48                            Rimas Entertainment LLC
# 49                           Sony Music Entertainment  >

# %%
# Obtiene los datos de la lista de reproducción
playlist_id = '37i9dQZF1DX0XUsuxWHRQd'
results = sp.playlist(playlist_id)

# Procesa los datos
tracks = results['tracks']['items']
playlist_data = []
for track in tracks:
    album = track['track']['album']
    track_data = {
        'Track Name': track['track']['name'],
        'Artist': track['track']['artists'][0]['name'],
        'Album': album['name'],
        'Release Date': album['release_date'],
        'Label': ''
    }

# Obtener información adicional del sello discográfico
    album_details = sp.album(album['id'])
    if 'label' in album_details:
        track_data['Label'] = album_details['label']
    playlist_data.append(track_data)

# Crea un DataFrame
df = pd.DataFrame(playlist_data)

# Exporta el DataFrame a un archivo CSV
df.to_csv('rap_caviar.csv', index=False)

# %%
df_rap_caviar = pd.read_csv('rap_caviar.csv')

df_rap_caviar
# Out:
#                                            Track Name
# 0                         All My Life (feat. J. Cole)  \
# 1                                         Ocean Spray
# 2                                     Search & Rescue
# 3                                             Go Hard
# 4             Trance (with Travis Scott & Young Thug)
# 5                       War Bout It (feat. 21 Savage)
# 6                                       Gunsmoke Town
# 7               Pissy (feat. Roddy Ricch, Nardo Wick)
# 8      Private Landing (feat. Justin Bieber & Future)
# 9               Peaches & Eggplants (feat. 21 Savage)
# 10                06 Gucci (feat. DaBaby & 21 Savage)
# 11                                         Area Codes
# 12                                         Pelle Coat
# 13                         My wrist (with Young Thug)
# 14                         Pain Talk (feat. Lil Tjay)
# 15       Pound Town 2 (feat. Nicki Minaj & Tay Keith)
# 16                                        Lick Or Sum
# 17                                            Act Bad
# 18                                        SLUT ME OUT
# 19                                         SHAKE SUMN
# 20            Watch This - ARIZONATEARS Pluggnb Remix
# 21                                        Spin Bout U
# 22       Favorite Song (feat. Future) [Toxic Version]
# 23                                         Motion God
# 24                                Turn The Streets Up
# 25                        GEEKALEEK (feat. Cash Kidd)
# 26                  Princess Diana (with Nicki Minaj)
# 27                                           Blackout
# 28                                         It's Crazy
# 29                                               Bops
# 30  Ring Ring (feat. Travis Scott, Don Toliver, Qu...
# 31                   Embarrassed (feat. Travis Scott)
# 32       I Remember (feat. Roddy Ricch & Kodak Black)
# 33                                 They Don't Love It
# 34                                    SORRY NOT SORRY
# 35                                  Fight The Feeling
# 36                                          Honey Bun
# 37                                             Andale
# 38                                 MVP (feat. G-Eazy)
# 39                      FreakyT (feat. Latto) - Remix
# 40                                           DOGTOOTH
# 41                                      Common Ground
# 42                                 Red Ruby Da Sleeze
# 43                                 Put It On Da Floor
# 44                           Hot Boy (feat. Lil Baby)
# 45                                   Strike (Holster)
# 46                            WTF (feat. Nicki Minaj)
# 47                                            No Good
# 48                                     I'M THAT BITCH
# 49                                     Keep Dat Nigga
#
#                         Artist
# 0                     Lil Durk  \
# 1                 Moneybagg Yo
# 2                        Drake
# 3                     Lil Baby
# 4                 Metro Boomin
# 5                     Lil Durk
# 6                  Kodak Black
# 7                   Gucci Mane
# 8                  Don Toliver
# 9                   Young Nudy
# 10                  Gucci Mane
# 11                        Kali
# 12                    Lil Durk
# 13                        Yeat
# 14               Sleepy Hallow
# 15                   Sexyy Red
# 16                    GloRilla
# 17                       Diddy
# 18                  NLE Choppa
# 19                      DaBaby
# 20                Lil Uzi Vert
# 21                       Drake
# 22                      Toosii
# 23                Moneybagg Yo
# 24                     EST Gee
# 25                     OHGEESY
# 26                   Ice Spice
# 27                Joyner Lucas
# 28                       J Hus
# 29                   Coi Leray
# 30                     CHASE B
# 31                 Don Toliver
# 32              Internet Money
# 33                 Jack Harlow
# 34          Tyler, The Creator
# 35                    Rod Wave
# 36                       Quavo
# 37                    DJ Drama
# 38      A Boogie Wit da Hoodie
# 39                   TiaCorine
# 40          Tyler, The Creator
# 41                 Jack Harlow
# 42                 Nicki Minaj
# 43                       Latto
# 44                  Nardo Wick
# 45                  Lil Yachty
# 46  YoungBoy Never Broke Again
# 47                  Juice WRLD
# 48                         BIA
# 49                      Icandy
#
#                                                 Album Release Date
# 0                         All My Life (feat. J. Cole)   2023-05-12  \
# 1                                         Ocean Spray   2023-05-24
# 2                                     Search & Rescue   2023-04-07
# 3                                             Go Hard   2023-05-03
# 4                                   HEROES & VILLAINS   2022-12-02
# 5                                       Almost Healed   2023-05-26
# 6                                    Pistolz & Pearlz   2023-05-26
# 7               Pissy (feat. Roddy Ricch, Nardo Wick)   2023-05-05
# 8                                           Love Sick   2023-02-24
# 9               Peaches & Eggplants (feat. 21 Savage)   2023-02-27
# 10                06 Gucci (feat. DaBaby & 21 Savage)   2023-03-31
# 11                                         Area Codes   2023-03-17
# 12                                      Almost Healed   2023-05-26
# 13                         My wrist (with Young Thug)   2023-05-26
# 14                         Pain Talk (feat. Lil Tjay)   2023-05-24
# 15       Pound Town 2 (feat. Nicki Minaj & Tay Keith)   2023-05-26
# 16                                        Lick Or Sum   2023-05-23
# 17                                            Act Bad   2023-05-26
# 18                                        SLUT ME OUT   2022-04-22
# 19                                    CALL DA FIREMAN   2023-05-05
# 20            Watch This (ARIZONATEARS Pluggnb Remix)   2023-02-05
# 21                                           Her Loss   2022-11-04
# 22       Favorite Song (feat. Future) [Toxic Version]   2023-05-19
# 23                                         Motion God   2023-04-21
# 24                                Turn The Streets Up   2023-05-25
# 25                        GEEKALEEK (feat. Cash Kidd)   2023-02-03
# 26                  Princess Diana (with Nicki Minaj)   2023-04-14
# 27                                           Blackout   2023-04-07
# 28                                         It's Crazy   2023-05-25
# 29                                               Bops   2023-04-27
# 30  Ring Ring (feat. Travis Scott, Don Toliver, Qu...   2023-05-11
# 31                                 Love Sick (Deluxe)   2023-02-28
# 32       I Remember (feat. Roddy Ricch & Kodak Black)   2023-03-24
# 33                                           Jackman.   2023-04-28
# 34           CALL ME IF YOU GET LOST: The Estate Sale   2023-03-31
# 35                                  Fight The Feeling   2023-03-31
# 36                                          Honey Bun   2023-03-31
# 37                               I'M REALLY LIKE THAT   2023-03-31
# 38                                 MVP (feat. G-Eazy)   2023-05-12
# 39                      FreakyT (feat. Latto) [Remix]   2023-04-21
# 40                                           DOGTOOTH   2023-03-27
# 41                                           Jackman.   2023-04-28
# 42                                 Red Ruby Da Sleeze   2023-03-03
# 43                                 Put It On Da Floor   2023-04-21
# 44                           Hot Boy (feat. Lil Baby)   2023-03-31
# 45                                   Strike (Holster)   2023-04-07
# 46                            WTF (feat. Nicki Minaj)   2023-04-07
# 47  Goodbye & Good Riddance (5 Year Anniversary Ed...   2023-05-18
# 48                                     I'M THAT BITCH   2023-03-24
# 49                                     Keep Dat Nigga   2022-12-19
#
#                                          Label
# 0                                        Alamo
# 1                CMG/N-Less/Interscope Records
# 2                         OVO/Republic Records
# 3         Quality Control Music/Motown Records
# 4                             Republic Records
# 5                                        Alamo
# 6                             Atlantic Records
# 7                                1017/Atlantic
# 8                       Cactus Jack / Atlantic
# 9           PDE Records/Same Plate/RCA Records
# 10                               1017/Atlantic
# 11                            Atlantic Records
# 12                                       Alamo
# 13        Field Trip Recordings/Geffen Records
# 14                  Winners Circle/RCA Records
# 15               Heavy On It/Open Shift/gamma.
# 16                      CMG/Interscope Records
# 17                                     Bad Boy
# 18                              Warner Records
# 19  South Coast Music Group/Interscope Records
# 20                           sped up nightcore
# 21                      OVO / Republic Records
# 22     South Coast Music Group/Capitol Records
# 23               CMG/N-Less/Interscope Records
# 24              CMG/Warlike/Interscope Records
# 25                            Atlantic Records
# 26                10K Projects/Capitol Records
# 27                     Twenty Nine Music Group
# 28                                Black Butter
# 29                   Uptown / Republic Records
# 30                  Artist Partner Group, Inc.
# 31                      Cactus Jack / Atlantic
# 32       Internet Money Records / 10K Projects
# 33                     Generation Now/Atlantic
# 34                                    Columbia
# 35                                       Alamo
# 36                  Quality Control Music, LLC
# 37                             MNRK Records LP
# 38               Atlantic/Highbridge The Label
# 39                South Coast Music Group, LLC
# 40                                    Columbia
# 41                     Generation Now/Atlantic
# 42                            Republic Records
# 43                       Streamcut/RCA Records
# 44                   Flawless Ent./RCA Records
# 45        Quality Control Music/Motown Records
# 46            Never Broke Again/Motown Records
# 47      Grade A Productions/Interscope Records
# 48                                        Epic
# 49                            Records/Columbia

# %%
def plot_pie_chart(dataframe):
    dataframe['Label'] = dataframe['Label'].replace({
        'Sony Music Entertainment': 'Sony Music',
        'Sony Music Latin': 'Sony Music',
        'Columbia Records/Duars Entertainment/Sony Musi...': 'Sony Music',
        'Sony Music Latin/DALE PLAY Records': 'Sony Music',
        'Sony Music Argentina': 'Sony Music',
        'Sony Music Latin/Duars Entertainment': 'Sony Music',
        'Columbia': 'Sony Music',
        'Columbia Records/Duars Entertainment/Sony Music Latin': 'Sony Music',
        'WM Spain': 'Warner Music',
        'WM Mexico': 'Warner Music',
        'WEA Latina': 'Warner Music',
        'WM Korea': 'Warner Music',
        'Warner Records': 'Warner Music',
        'UMLE - Latino': 'Universal Music',
        'Universal Music Spain S.L.': 'Universal Music',
        'Virgin Music Spain': 'Universal Music',
        'Universal Music Argentina S.A.': 'Universal Music',
        'Universal Music AB': 'Universal Music',
        'Republic Records': 'Universal Music',
        'Universal Republic Records': 'Universal Music',
        'Universal-Island Records Ltd.': 'Universal Music',
        'OVO/Republic Records': 'Universal Music',
        'Universal Music Mexico': 'Universal Music',
        'XO / Republic Records': 'Universal Music'
    })
    
    frecuencias = dataframe['Label'].value_counts()
    valores_unicos = frecuencias[frecuencias == 1].index
    dataframe.loc[dataframe['Label'].isin(valores_unicos), 'Label'] = 'Otros'
    
    porcentajes = dataframe['Label'].value_counts(normalize=True) * 100
    valores = porcentajes.values
    etiquetas = [f'{etiqueta} ({porcentaje:.1f}%)' for etiqueta, porcentaje in zip(porcentajes.index, porcentajes.values)]
    
    plt.pie(valores, labels=etiquetas, autopct='%1.1f%%')
    plt.title('Distribución de Sellos Discográficos')
    plt.show()

# %%
plot_pie_chart(df_rap_caviar)

# %%
df_merge_rap_int = pd.merge(df_int[['Track Name','Artist', 'Label']], df_rap_caviar[['Track Name','Artist', 'Label']], on=['Track Name','Artist', 'Label'], how='inner')

df_merge_rap_int
# Out:
#         Track Name      Artist                 Label
# 0  Search & Rescue       Drake  OVO/Republic Records
# 1      SLUT ME OUT  NLE Choppa        Warner Records

# %%
plot_pie_chart (df_merge_rap_int)

# %%
df_merge_lista_pop_int = pd.merge(df_la_lista_pop[['Track Name','Artist', 'Label']], df_esp[['Track Name','Artist', 'Label']], on=['Track Name','Artist', 'Label'], how='inner')

df_merge_lista_pop_int
# Out:
# Empty DataFrame
# Columns: [Track Name, Artist, Label]
# Index: []

# %%
# Siguiente dataset...
# df_2.head()
